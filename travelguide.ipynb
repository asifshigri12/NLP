# %% [markdown]
# <a href="https://colab.research.google.com/github/asifshigri12/NLP/blob/main/travelguide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio transformers

# %%
import gradio as gr
import random
import json

# %%
import gradio as gr
import requests

# Replace 'your_groq_api_key' with your actual Groq API key
GROQ_API_KEY = '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'
# Comprehensive travel data for various locations in Pakistan
travel_data = {
    "Islamabad": {
        "visiting_spots": [
            {"name": "Faisal Mosque", "description": "A beautiful mosque located at the base of the Margalla Hills."},
            {"name": "Daman-e-Koh", "description": "A viewpoint offering panoramic views of Islamabad."},
            {"name": "Shakarparian Park", "description": "A park offering beautiful walking paths and gardens."}
        ],
        "activities": [
            "Hiking in Margalla Hills",
            "Shopping at Centaurus Mall",
            "Dining at local restaurants"
        ],
        "vehicle_charges": "PKR 5,000 per day for a car without fuel",
        "hotels": [
            {"name": "Marriott Hotel", "price": "PKR 15,000 per night"},
            {"name": "Islamabad Serena Hotel", "price": "PKR 18,000 per night"},
            {"name": "Hotel One", "price": "PKR 10,000 per night"}
        ],
        "duration": "2 days",
        "jeep_required": True,
        "distance": "0 km from Rawalpindi"
    },
    "Lahore": {
        "visiting_spots": [
            {"name": "Lahore Fort", "description": "A UNESCO World Heritage Site with stunning architecture."},
            {"name": "Badshahi Mosque", "description": "One of the largest mosques in the world."},
            {"name": "Shalimar Gardens", "description": "Beautiful Mughal-era gardens."}
        ],
        "activities": [
            "Street food tours",
            "Cultural shows",
            "Shopping at Anarkali Bazaar"
        ],
        "vehicle_charges": "PKR 5,000 per day for a car",
        "hotels": [
            {"name": "Pearl Continental Hotel", "price": "PKR 12,000 per night"},
            {"name": "Mövenpick Hotel", "price": "PKR 16,000 per night"},
            {"name": "Gulberg Hotel", "price": "PKR 8,000 per night"}
        ],
        "duration": "2 days",
        "jeep_required": False,
        "distance": "400 km from Islamabad"
    },
    "Karachi": {
        "visiting_spots": [
            {"name": "Clifton Beach", "description": "A popular beach destination with a vibrant atmosphere."},
            {"name": "Mohatta Palace", "description": "A museum showcasing the history of Karachi."},
            {"name": "Pakistan Maritime Museum", "description": "A maritime museum with exhibits related to Pakistan's naval history."}
        ],
        "activities": [
            "Shopping at Dolmen Mall",
            "Dining at seaside restaurants",
            "Visiting the historic sites"
        ],
        "vehicle_charges": "PKR 5,000 per day for a car",
        "hotels": [
            {"name": "Shangri-La Hotel", "price": "PKR 20,000 per night"},
            {"name": "Marriott Karachi", "price": "PKR 15,000 per night"},
            {"name": "Hotel One Karachi", "price": "PKR 10,000 per night"}
        ],
        "duration": "3 days",
        "jeep_required": False,
        "distance": "15 km from the city center"
    },
    "Murree": {
        "visiting_spots": [
            {"name": "Mall Road", "description": "The main shopping street with various shops and eateries."},
            {"name": "Pindi Point", "description": "A viewpoint offering stunning views of the surrounding hills."},
            {"name": "Patriata (New Murree)", "description": "Famous for its chair lift and cable car rides."}
        ],
        "activities": [
            "Hiking in the nearby hills",
            "Shopping for souvenirs",
            "Enjoying the cool weather"
        ],
        "vehicle_charges": "PKR 6,000 per day for a car",
        "hotels": [
            {"name": "Murree Regency Hotel", "price": "PKR 8,000 per night"},
            {"name": "Pearl Continental Hotel", "price": "PKR 12,000 per night"},
            {"name": "Grand Hotel Murree", "price": "PKR 10,000 per night"}
        ],
        "duration": "2 days",
        "jeep_required": True,
        "distance": "60 km from Islamabad"
    },
    "Skardu": {
        "visiting_spots": [
            {"name": "Shangrila Resort", "description": "A stunning resort located by the lake."},
            {"name": "Deosai National Park", "description": "Famous for its wildlife and scenic beauty."},
            {"name": "Kachura Lakes", "description": "Beautiful lakes surrounded by mountains."},
            {"name": "Basho Valley", "description": "Beautiful meadows surrounded by mountains."},
            {"name": "Katapana Desert", "description": "Beautiful desert surrounded by mountains."},
            {"name": "Manthokha Waterfall", "description": "Beautiful waterfall falling from the mountains."}
        ],
        "activities": [
            "Camping in Deosai",
            "Fishing in the lakes",
            "Photography of breathtaking landscapes"
        ],
        "vehicle_charges": "PKR 7,000 per day for a jeep",
        "hotels": [
            {"name": "Skardu Inn", "price": "PKR 6,000 per night"},
            {"name": "Kachura Lake Resort", "price": "PKR 10,000 per night"},
            {"name": "Shangrila Resort", "price": "PKR 30,000 per night"},
            {"name": "Khoj Shigar", "price": "PKR 30,000 per night"}
        ],
        "duration": "5 days",
        "jeep_required": True,
        "distance": "17 km from Skardu International Airport"
    },
    "Hunza": {
        "visiting_spots": [
            {"name": "Karimabad", "description": "A scenic town with beautiful views of the Hunza valley."},
            {"name": "Baltit Fort", "description": "A historical fort with stunning architecture."},
            {"name": "Attabad Lake", "description": "A stunning lake formed after a landslide."}
        ],
        "activities": [
            "Trekking to Ultar Sar Base Camp",
            "Exploring local markets",
            "Boat rides on Attabad Lake"
        ],
        "vehicle_charges": "PKR 6,500 per day for a jeep",
        "hotels": [
            {"name": "Hunza Serena Inn", "price": "PKR 20,000 per night"},
            {"name": "Baltit Inn", "price": "PKR 8,000 per night"},
            {"name": "Eagle's Nest Hotel", "price": "PKR 16,000 per night"}
        ],
        "duration": "3 days",
        "jeep_required": True,
        "distance": "130 km from Gilgit"
    },
    "Fairy Meadows": {
        "visiting_spots": [
            {"name": "Nanga Parbat Base Camp", "description": "A trek to the base camp of the world's ninth-highest mountain."},
            {"name": "Fairy Meadows", "description": "A stunning grassland with breathtaking views."}
        ],
        "activities": [
            "Camping under the stars",
            "Hiking in the lush meadows",
            "Photography of Nanga Parbat"
        ],
        "vehicle_charges": "PKR 7,000 per day for a jeep",
        "hotels": [
            {"name": "Fairy Meadows Hotel", "price": "PKR 5,000 per night"},
            {"name": "Camping Tents", "price": "PKR 3,000 per night"}
        ],
        "duration": "3 days",
        "jeep_required": True,
        "distance": "70 km from Raikot Bridge"
    },
    "Naran": {
        "visiting_spots": [
            {"name": "Saif-ul-Malook Lake", "description": "A beautiful lake famous for its stunning scenery."},
            {"name": "Naran Bazar", "description": "A bustling market with local handicrafts."}
        ],
        "activities": [
            "Boating in Saif-ul-Malook",
            "Exploring nearby hiking trails",
            "Shopping for local crafts"
        ],
        "vehicle_charges": "PKR 5,000 per day for a car",
        "hotels": [
            {"name": "Kunhar River Side", "price": "PKR 15,000 per night"},
            {"name": "Naran Hills", "price": "PKR 3,000 per night"}
        ],
        "duration": "2 days",
        "jeep_required": True,
        "distance": "240 km from Islamabad"
    },
    "Sawat": {
    "visiting_spots": [
        {"name": "Malam Jabba", "description": "A beautiful hill station known for skiing and stunning landscapes."},
        {"name": "Kalam Valley", "description": "A picturesque valley famous for its lush green scenery and rivers."},
        {"name": "Utror Valley", "description": "A serene valley with beautiful meadows and mountains."}
    ],
    "activities": [
        "Skiing in Malam Jabba",
        "Boating in Mahodand Lake",
        "Hiking in the surrounding hills"
    ],
    "vehicle_charges": "PKR 6,000 per day for a jeep",
    "hotels": [
        {"name": "Malam Jabba Resort", "price": "PKR 12,000 per night"},
        {"name": "Kalam Hotel", "price": "PKR 8,000 per night"},
        {"name": "Kalam Inn", "price": "PKR 5,000 per night"}
    ],
    "duration": "3 days",
    "jeep_required": True,
    "distance": "280 km from Islamabad"
},
    "Chitral": {
    "visiting_spots": [
        {"name": "Kalash Valley", "description": "Famous for its unique culture and stunning landscapes."},
        {"name": "Chitral Fort", "description": "A historic fort offering panoramic views of the valley."},
        {"name": "Shandur Pass", "description": "Known as the world's highest polo ground."}
    ],
    "activities": [
        "Exploring the Kalash culture",
        "Trekking in the surrounding mountains",
        "Participating in local polo matches"
    ],
    "vehicle_charges": "PKR 7,000 per day for a jeep",
    "hotels": [
        {"name": "Chitral Palace Hotel", "price": "PKR 10,000 per night"},
        {"name": "Al-Madina Hotel", "price": "PKR 4,500 per night"},
        {"name": "Shandur Hotel", "price": "PKR 3,500 per night"}
    ],
    "duration": "4 days",
    "jeep_required": True,
    "distance": "350 km from Islamabad"
},
    "Shigar": {
    "visiting_spots": [
        {"name": "Shigar Fort", "description": "A historic fort with beautiful architecture and stunning views."},
        {"name": "Khaplu Valley", "description": "Known for its breathtaking landscapes and rich culture."},
        {"name": "Bruno Glacier", "description": "A beautiful glacier perfect for trekking and photography."}
    ],
    "activities": [
        "Visiting Shigar Fort",
        "Trekking to nearby glaciers",
        "Exploring local villages"
    ],
    "vehicle_charges": "PKR 6,000 per day for a jeep",
    "hotels": [
        {"name": "Shigar Fort Residence", "price": "PKR 12,000 per night"},
        {"name": "Shigar Inn", "price": "PKR 5,000 per night"},
        {"name": "K2 Motel", "price": "PKR 4,000 per night"}
    ],
    "duration": "3 days",
    "jeep_required": True,
    "distance": "700 km from Islamabad"
},
    "Astore": {
    "visiting_spots": [
        {"name": "Ratti Gali Lake", "description": "A stunning alpine lake surrounded by snow-capped peaks."},
        {"name": "Nanga Parbat Base Camp", "description": "A trek that offers breathtaking views of the world's ninth-highest mountain."},
        {"name": "Astore River", "description": "A serene river known for its clear waters and picturesque surroundings."}
    ],
    "activities": [
        "Trekking to Ratti Gali Lake",
        "Camping at Nanga Parbat Base Camp",
        "Fishing in Astore River"
    ],
    "vehicle_charges": "PKR 5,500 per day for a jeep",
    "hotels": [
        {"name": "Astore Valley Hotel", "price": "PKR 8,000 per night"},
        {"name": "Ratti Gali Resort", "price": "PKR 6,500 per night"},
        {"name": "Kachura Lake Inn", "price": "PKR 4,500 per night"}
    ],
    "duration": "3 days",
    "jeep_required": True,
    "distance": "300 km from Islamabad"
    }
}
def get_travel_info(location):
    location = location.capitalize()  # Ensure the input is properly cased
    if location in travel_data:
        details = travel_data[location]
        visiting_spots = "\n".join([f"{spot['name']}: {spot['description']}" for spot in details['visiting_spots']])
        activities = "\n".join(details['activities'])
        hotels = "\n".join([f"{hotel['name']}: {hotel['price']}" for hotel in details['hotels']])

        return (f"**Location**: {location}\n\n"
                f"**Visiting Spots**:\n{visiting_spots}\n\n"
                f"**Activities**:\n{activities}\n\n"
                f"**Vehicle Charges**: {details['vehicle_charges']}\n"
                f"**Hotels**:\n{hotels}\n\n"
                f"**Duration**: {details['duration']}\n"
                f"**Jeep Required**: {'Yes' if details['jeep_required'] else 'No'}\n"
                f"**Distance**: {details['distance']}")
    return "Location not found."

# Create Gradio interface
interface = gr.Interface(fn=get_travel_info, inputs="text", outputs="markdown",
                         title="Travel Guide for Pakistan",
                         description="Enter the location name to get travel information.")

# Launch the Gradio app
interface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1abb52d3fe138414ca.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1abb52d3fe138414ca.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
